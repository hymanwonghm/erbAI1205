# %%
# TensorFlow and tf.keras
import tensorflow as tf

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
train_images.shape
len(train_labels)

# %%
test_images.shape
len(test_labels)

# %%
plt.figure()
plt.imshow(train_images[0])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
train_images = train_images / 255.0 # training data
test_images = test_images / 255.0 # testing data

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %%
'''
TODO: Create your Sequential model here, add 1 flatten layer with input shape (28, 28),
followed by 1 dense layer setting units as 128 with relu as activation function,
followed by 1 denst layer setting units as 10

https://www.tensorflow.org/api_docs/python/tf/keras/layers/Flatten
https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dense
'''

# %%
'''
TODO: compile the model, use adam as optimizer,
use SparseCategoricalCrossentropy as loss function setting from_logits as True,
use 'accuracy' as metrics

https://www.tensorflow.org/api_docs/python/tf/keras/losses/SparseCategoricalCrossentropy
'''

# %%
# TODO: fit the model with training images and training labels, setting epochs as 10

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
print(f'Test loss: {test_loss}, Test accuracy: {test_acc}')

# %%
probability_model = tf.keras.Sequential([model, tf.keras.layers.Softmax()])
predictions = probability_model.predict(test_images)
np.argmax(predictions[0])

# %%
test_labels[0]
